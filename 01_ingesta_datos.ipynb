# %%
# %% [markdown]
# # Notebook 01: Ingesta de Datos
#
# **Objetivo**: Descargar y cargar datos de contratos públicos desde la API de Datos Abiertos Colombia (SECOP II).
#
# **Dataset**: SECOP II - Contratos Electrónicos
#
# **Fuente**: https://www.datos.gov.co/Gastos-Gubernamentales/SECOP-II-Contratos-Electr-nicos/jbjy-vk9h
#
# ## Actividades:
# 1. Configurar SparkSession con Delta Lake
# 2. Descargar dataset usando API Socrata (opcional) o leer CSV local
# 3. Explorar esquema inicial
# 4. Guardar en formato Parquet optimizado

# %%
# Importar librerías
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, to_date, year, month
import os

# %%
# Configurar SparkSession
# Conectamos al cluster Spark Master
spark = SparkSession.builder \
    .appName("SECOP_Ingesta") \
    .master("local[*]") \
    .config("spark.executor.memory", "2g") \
    .config("spark.driver.memory", "1g") \
    .getOrCreate()

print(f"Spark Version: {spark.version}")
print(f"Spark Master: {spark.sparkContext.master}")

# %%
# OPCIÓN 1: Descargar datos desde API de Datos Abiertos Colombia
# Nota: Este dataset puede ser muy grande (varios GB), por lo que limitamos a 100k registros
# Para producción, considera descargar el CSV completo manualmente

# Dataset ID: jbjy-vk9h
# API Endpoint: https://www.datos.gov.co/resource/jbjy-vk9h.json

print("Descargando datos desde API Socrata...")
print("Nota: Limitamos a 100,000 registros para el ejercicio práctico")

# Usando requests para descargar datos (alternativa a sodapy)
import requests
import json

# URL de la API con límite de registros
api_url = "https://www.datos.gov.co/resource/jbjy-vk9h.json?$limit=1000"

response = requests.get(api_url)
data = response.json()

print(f"Registros descargados: {len(data)}")

# Guardar JSON localmente
json_path = "/opt/spark-data/raw/secop_contratos.json"
os.makedirs(os.path.dirname(json_path), exist_ok=True)

with open(json_path, 'w', encoding='utf-8') as f:
    for record in data:
        f.write(json.dumps(record, ensure_ascii=False) + '\n')

print(f"Datos guardados en: {json_path}")

# %%
# OPCIÓN 2: Leer desde JSON descargado
print("Leyendo datos desde JSON...")
df_raw = spark.read.json(json_path)

print(f"Total de registros: {df_raw.count()}")
print(f"Total de columnas: {len(df_raw.columns)}")

# %%
# Explorar esquema del dataset
print("\n=== ESQUEMA DEL DATASET ===")
df_raw.printSchema()

# %%
# Mostrar primeras filas
print("\n=== PRIMERAS 5 FILAS ===")
df_raw.show(5, truncate=False)

# %%
# Mostrar nombres de columnas
print("\n=== COLUMNAS DISPONIBLES ===")
for col_name in df_raw.columns:
    print(f"- {col_name}")

# %%
# Estadísticas básicas del dataset
print("\n=== INFORMACIÓN DEL DATASET ===")
print(f"Registros totales: {df_raw.count():,}")
print(f"Columnas totales: {len(df_raw.columns)}")

# %%
# Seleccionar columnas clave para el análisis de ML
# Nota: Los nombres de columnas pueden variar según la versión del dataset
# Ajusta según las columnas disponibles

columnas_clave = [
    "referencia_del_contrato",
    "nit_entidad",
    "nombre_entidad",
    "departamento",
    "ciudad",
    "tipo_de_contrato",
    "valor_del_contrato",
    "fecha_de_firma",
    "plazo",
    "plazo_de_ejec_del_contrato",
    "nombre_del_proveedor",
    "estado_contrato"
]

# Verificar qué columnas existen realmente
columnas_disponibles = [col for col in columnas_clave if col in df_raw.columns]
print(f"\n=== COLUMNAS SELECCIONADAS ({len(columnas_disponibles)}) ===")
for col in columnas_disponibles:
    print(f"- {col}")

# %%
# Filtrar columnas disponibles
if columnas_disponibles:
    df_clean = df_raw.select(*columnas_disponibles)
else:
    # Si no encontramos las columnas esperadas, usamos todas
    print("ADVERTENCIA: No se encontraron las columnas esperadas. Usando todas las columnas.")
    df_clean = df_raw

# %%
# Guardar en formato Parquet optimizado
output_path = "/opt/spark-data/raw/secop_contratos.parquet"
print(f"\n=== GUARDANDO EN FORMATO PARQUET ===")
print(f"Ruta: {output_path}")

df_clean.write \
    .mode("overwrite") \
    .parquet(output_path)

print("Datos guardados exitosamente en formato Parquet")

# %%
# Verificar que el archivo se guardó correctamente
print("\n=== VERIFICACIÓN ===")
df_verificacion = spark.read.parquet(output_path)
print(f"Registros en Parquet: {df_verificacion.count():,}")
print(f"Columnas en Parquet: {len(df_verificacion.columns)}")

# %%
# Resumen final
print("\n" + "="*60)
print("RESUMEN DE INGESTA")
print("="*60)
print(f"✓ Datos descargados desde API Socrata")
print(f"✓ Registros procesados: {df_clean.count():,}")
print(f"✓ Formato de salida: Parquet")
print(f"✓ Ubicación: {output_path}")
print("="*60)

# %%
# Detener SparkSession
spark.stop()
print("SparkSession finalizada")
# Out:
# Spark Version: 3.5.0
# Spark Master: local[*]
# Descargando datos desde API Socrata...
# Nota: Limitamos a 100,000 registros para el ejercicio práctico
# Registros descargados: 1000
# Datos guardados en: /opt/spark-data/raw/secop_contratos.json
# Leyendo datos desde JSON...
# Total de registros: 1000
# Total de columnas: 87
#
# === ESQUEMA DEL DATASET ===
# root
#  |-- anno_bpin: string (nullable = true)
#  |-- c_digo_bpin: string (nullable = true)
#  |-- ciudad: string (nullable = true)
#  |-- codigo_de_categoria_principal: string (nullable = true)
#  |-- codigo_entidad: string (nullable = true)
#  |-- codigo_proveedor: string (nullable = true)
#  |-- condiciones_de_entrega: string (nullable = true)
#  |-- departamento: string (nullable = true)
#  |-- descripcion_del_proceso: string (nullable = true)
#  |-- descripcion_documentos_tipo: string (nullable = true)
#  |-- destino_gasto: string (nullable = true)
#  |-- dias_adicionados: string (nullable = true)
#  |-- documento_proveedor: string (nullable = true)
#  |-- documentos_tipo: string (nullable = true)
#  |-- domicilio_representante_legal: string (nullable = true)
#  |-- duraci_n_del_contrato: string (nullable = true)
#  |-- el_contrato_puede_ser_prorrogado: string (nullable = true)
#  |-- entidad_centralizada: string (nullable = true)
#  |-- es_grupo: string (nullable = true)
#  |-- es_pyme: string (nullable = true)
#  |-- espostconflicto: string (nullable = true)
#  |-- estado_bpin: string (nullable = true)
#  |-- estado_contrato: string (nullable = true)
#  |-- fecha_de_fin_del_contrato: string (nullable = true)
#  |-- fecha_de_firma: string (nullable = true)
#  |-- fecha_de_inicio_del_contrato: string (nullable = true)
#  |-- fecha_de_notificaci_n_de_prorrogaci_n: string (nullable = true)
#  |-- fecha_fin_liquidacion: string (nullable = true)
#  |-- fecha_inicio_liquidacion: string (nullable = true)
#  |-- g_nero_representante_legal: string (nullable = true)
#  |-- habilita_pago_adelantado: string (nullable = true)
#  |-- id_contrato: string (nullable = true)
#  |-- identificaci_n_representante_legal: string (nullable = true)
#  |-- justificacion_modalidad_de: string (nullable = true)
#  |-- liquidaci_n: string (nullable = true)
#  |-- localizaci_n: string (nullable = true)
#  |-- modalidad_de_contratacion: string (nullable = true)
#  |-- n_mero_de_cuenta: string (nullable = true)
#  |-- n_mero_de_documento_ordenador_de_pago: string (nullable = true)
#  |-- n_mero_de_documento_ordenador_del_gasto: string (nullable = true)
#  |-- n_mero_de_documento_supervisor: string (nullable = true)
#  |-- nacionalidad_representante_legal: string (nullable = true)
#  |-- nit_entidad: string (nullable = true)
#  |-- nombre_del_banco: string (nullable = true)
#  |-- nombre_entidad: string (nullable = true)
#  |-- nombre_ordenador_de_pago: string (nullable = true)
#  |-- nombre_ordenador_del_gasto: string (nullable = true)
#  |-- nombre_representante_legal: string (nullable = true)
#  |-- nombre_supervisor: string (nullable = true)
#  |-- objeto_del_contrato: string (nullable = true)
#  |-- obligaci_n_ambiental: string (nullable = true)
#  |-- obligaciones_postconsumo: string (nullable = true)
#  |-- orden: string (nullable = true)
#  |-- origen_de_los_recursos: string (nullable = true)
#  |-- pilares_del_acuerdo: string (nullable = true)
#  |-- presupuesto_general_de_la_nacion_pgn: string (nullable = true)
#  |-- proceso_de_compra: string (nullable = true)
#  |-- proveedor_adjudicado: string (nullable = true)
#  |-- puntos_del_acuerdo: string (nullable = true)
#  |-- rama: string (nullable = true)
#  |-- recursos_de_credito: string (nullable = true)
#  |-- recursos_propios: string (nullable = true)
#  |-- recursos_propios_alcald_as_gobernaciones_y_resguardos_ind_genas_: string (nullable = true)
#  |-- referencia_del_contrato: string (nullable = true)
#  |-- reversion: string (nullable = true)
#  |-- saldo_cdp: string (nullable = true)
#  |-- saldo_vigencia: string (nullable = true)
#  |-- sector: string (nullable = true)
#  |-- sistema_general_de_participaciones: string (nullable = true)
#  |-- sistema_general_de_regal_as: string (nullable = true)
#  |-- tipo_de_contrato: string (nullable = true)
#  |-- tipo_de_cuenta: string (nullable = true)
#  |-- tipo_de_documento_ordenador_de_pago: string (nullable = true)
#  |-- tipo_de_documento_ordenador_del_gasto: string (nullable = true)
#  |-- tipo_de_documento_supervisor: string (nullable = true)
#  |-- tipo_de_identificaci_n_representante_legal: string (nullable = true)
#  |-- tipodocproveedor: string (nullable = true)
#  |-- ultima_actualizacion: string (nullable = true)
#  |-- urlproceso: struct (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- valor_amortizado: string (nullable = true)
#  |-- valor_de_pago_adelantado: string (nullable = true)
#  |-- valor_del_contrato: string (nullable = true)
#  |-- valor_facturado: string (nullable = true)
#  |-- valor_pagado: string (nullable = true)
#  |-- valor_pendiente_de: string (nullable = true)
#  |-- valor_pendiente_de_ejecucion: string (nullable = true)
#  |-- valor_pendiente_de_pago: string (nullable = true)
#
#
# === PRIMERAS 5 FILAS ===
# +---------+-----------+----------+-----------------------------+--------------+----------------+-------------------------+--------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------+--------------+----------------+-------------------+---------------+----------------------------------------+---------------------+--------------------------------+--------------------+--------+-------+---------------+-----------+---------------+-------------------------+-----------------------+----------------------------+-------------------------------------+---------------------+------------------------+--------------------------+------------------------+------------------+----------------------------------+--------------------------------------------+-----------+------------------------------+-----------------------------+----------------+-------------------------------------+---------------------------------------+------------------------------+--------------------------------+-----------+----------------+---------------------------------------------+------------------------+------------------------------+--------------------------------+-------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------+------------------------+-----------+----------------------+-------------------+------------------------------------+-----------------+--------------------------------+------------------+--------------------+-------------------+----------------+----------------------------------------------------------------+-----------------------+---------+---------+--------------+--------------------------------------------------+----------------------------------+---------------------------+-----------------------+--------------+-----------------------------------+-------------------------------------+----------------------------+------------------------------------------+--------------------+-----------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+------------------------+------------------+---------------+------------+------------------+----------------------------+-----------------------+
# |anno_bpin|c_digo_bpin|ciudad    |codigo_de_categoria_principal|codigo_entidad|codigo_proveedor|condiciones_de_entrega   |departamento              |descripcion_del_proceso                                                                                                                                                                                                                                                                          |descripcion_documentos_tipo|destino_gasto |dias_adicionados|documento_proveedor|documentos_tipo|domicilio_representante_legal           |duraci_n_del_contrato|el_contrato_puede_ser_prorrogado|entidad_centralizada|es_grupo|es_pyme|espostconflicto|estado_bpin|estado_contrato|fecha_de_fin_del_contrato|fecha_de_firma         |fecha_de_inicio_del_contrato|fecha_de_notificaci_n_de_prorrogaci_n|fecha_fin_liquidacion|fecha_inicio_liquidacion|g_nero_representante_legal|habilita_pago_adelantado|id_contrato       |identificaci_n_representante_legal|justificacion_modalidad_de                  |liquidaci_n|localizaci_n                  |modalidad_de_contratacion    |n_mero_de_cuenta|n_mero_de_documento_ordenador_de_pago|n_mero_de_documento_ordenador_del_gasto|n_mero_de_documento_supervisor|nacionalidad_representante_legal|nit_entidad|nombre_del_banco|nombre_entidad                               |nombre_ordenador_de_pago|nombre_ordenador_del_gasto    |nombre_representante_legal      |nombre_supervisor        |objeto_del_contrato                                                                                                                                                                                                                                                                              |obligaci_n_ambiental|obligaciones_postconsumo|orden      |origen_de_los_recursos|pilares_del_acuerdo|presupuesto_general_de_la_nacion_pgn|proceso_de_compra|proveedor_adjudicado            |puntos_del_acuerdo|rama                |recursos_de_credito|recursos_propios|recursos_propios_alcald_as_gobernaciones_y_resguardos_ind_genas_|referencia_del_contrato|reversion|saldo_cdp|saldo_vigencia|sector                                            |sistema_general_de_participaciones|sistema_general_de_regal_as|tipo_de_contrato       |tipo_de_cuenta|tipo_de_documento_ordenador_de_pago|tipo_de_documento_ordenador_del_gasto|tipo_de_documento_supervisor|tipo_de_identificaci_n_representante_legal|tipodocproveedor    |ultima_actualizacion   |urlproceso                                                                                                                                             |valor_amortizado|valor_de_pago_adelantado|valor_del_contrato|valor_facturado|valor_pagado|valor_pendiente_de|valor_pendiente_de_ejecucion|valor_pendiente_de_pago|
# +---------+-----------+----------+-----------------------------+--------------+----------------+-------------------------+--------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------+--------------+----------------+-------------------+---------------+----------------------------------------+---------------------+--------------------------------+--------------------+--------+-------+---------------+-----------+---------------+-------------------------+-----------------------+----------------------------+-------------------------------------+---------------------+------------------------+--------------------------+------------------------+------------------+----------------------------------+--------------------------------------------+-----------+------------------------------+-----------------------------+----------------+-------------------------------------+---------------------------------------+------------------------------+--------------------------------+-----------+----------------+---------------------------------------------+------------------------+------------------------------+--------------------------------+-------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------+------------------------+-----------+----------------------+-------------------+------------------------------------+-----------------+--------------------------------+------------------+--------------------+-------------------+----------------+----------------------------------------------------------------+-----------------------+---------+---------+--------------+--------------------------------------------------+----------------------------------+---------------------------+-----------------------+--------------+-----------------------------------+-------------------------------------+----------------------------+------------------------------------------+--------------------+-----------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+------------------------+------------------+---------------+------------+------------------+----------------------------+-----------------------+
# |No D     |No Definido|Bogotá    |V1.94131603                  |703840058     |701645640       |Como acordado previamente|Distrito Capital de Bogotá|PRESTAR SERVICIOS PROFESIONALES EN EL APOYO Y ACOMPAÑAMIENTO A LA SECRETARÍA EJECUTIVA EN LA CONTESTACIÓN Y SEGUIMIENTO A ACCIONES CONSTITUCIONALES Y PETICIONES DE CONTENIDO JURÍDICO Y DEMÁS ASUNTOS RELACIONADOS CON LA SECRETARÍA EJECUTIVA PROPIOS DE SU COMPETENCIA Y EN EL MARCO DE LA JEP|No definido                |Inversión     |0               |52993826           |No             |AV. CLL 57r Sur 73i 35 torre 3 apto 2527|No definido          |No                              |Centralizada        |No      |No     |Si             |No Válido  |Cancelado      |2020-12-21T00:00:00.000  |NULL                   |2020-02-13T00:00:00.000     |NULL                                 |NULL                 |NULL                    |No Definido               |No Definido             |CO1.PCCNTR.1370606|52993826                          |Regla aplicable                             |No         |Colombia, Bogotá,  Bogotá     |Contratación régimen especial|No definido     |No definido                          |No definido                            |No definido                   |CO                              |901140004  |No definido     |JEP                                          |No definido             |No definido                   |MARCELA TRINIDAD RODRIGUEZ URIBE|No definido              |PRESTAR SERVICIOS PROFESIONALES EN EL APOYO Y ACOMPAÑAMIENTO A LA SECRETARÍA EJECUTIVA EN LA CONTESTACIÓN Y SEGUIMIENTO A ACCIONES CONSTITUCIONALES Y PETICIONES DE CONTENIDO JURÍDICO Y DEMÁS ASUNTOS RELACIONADOS CON LA SECRETARÍA EJECUTIVA PROPIOS DE SU COMPETENCIA Y EN EL MARCO DE LA JEP|No                  |No                      |Nacional   |Distribuido           |JusticiaYVerdad    |0                                   |CO1.BDOS.1108279 |MARCELA TRINIDAD RODRIGUEZ URIBE|VictimasConflicto |Corporación Autónoma|0                  |0               |0                                                               |JEP-119-2020           |No       |79299050 |0             |No aplica/No pertenece                            |0                                 |0                          |Prestación de servicios|No Definido   |No definido                        |No definido                          |No definido                 |Cédula de Ciudadanía                      |Cédula de Ciudadanía|NULL                   |{https://community.secop.gov.co/Public/Tendering/OpportunityDetail/Index?noticeUID=CO1.NTC.1106460&isFromPublicArea=True&isModal=true&asPopupView=true}|0               |0                       |73451015          |0              |0           |0                 |73451015                    |73451015               |
# |No D     |No Definido|Arauca    |V1.80111600                  |700586134     |712180066       |Como acordado previamente|Arauca                    |PRESTACION DE SERVICIOS DE APOYO A LA GESTION COMO AUXILIAR DE SERVICIOS GENERALES Y CAFETERIA EN LA OFICINA DE JURIDICA; OFICINA DE PRENSA; RECEPCION; SOTANO Y ESCALERAS DEL FRENTE DEL MUNICIPIO DE ARAUCA                                                                                    |No definido                |Funcionamiento|0               |1007167824         |No             |No Definido                             |143 Dia(s)           |No                              |Descentralizada     |No      |No     |No             |No Válido  |Cerrado        |2022-12-27T00:00:00.000  |2022-08-04T00:00:00.000|2022-08-05T00:00:00.000     |NULL                                 |NULL                 |NULL                    |Mujer                     |No                      |CO1.PCCNTR.3878896|Sin Descripcion                   |Servicios profesionales y apoyo a la gestión|No         |Colombia,  Arauca ,  Arauca   |Contratación directa         |No definido     |No definido                          |No definido                            |No definido                   |CO                              |800102504  |No definido     |ALCALDIA MUNICIPIO DE ARAUCA                 |No definido             |No definido                   |YORLY ENILSE SANTOS CELY        |No definido              |PRESTACION DE SERVICIOS DE APOYO A LA GESTION COMO AUXILIAR DE SERVICIOS GENERALES Y CAFETERIA EN LA OFICINA DE JURIDICA; OFICINA DE PRENSA; RECEPCION; SOTANO Y ESCALERAS DEL FRENTE DEL MUNICIPIO DE ARAUCA                                                                                    |No                  |No                      |Territorial|Distribuido           |No aplica          |0                                   |CO1.BDOS.3106524 |YORLY ENILSE SANTOS CELY        |No aplica         |Ejecutivo           |0                  |0               |6673341                                                         |CONTRATO 000388-2022   |No       |7920000  |0             |Servicio Público                                  |0                                 |0                          |Prestación de servicios|No Definido   |No definido                        |No definido                          |No definido                 |Sin Descripcion                           |Cédula de Ciudadanía|2023-07-05T00:00:00.000|{https://community.secop.gov.co/Public/Tendering/OpportunityDetail/Index?noticeUID=CO1.NTC.3108452&isFromPublicArea=True&isModal=true&asPopupView=true}|0               |0                       |6673341           |0              |0           |0                 |6673341                     |6673341                |
# |No D     |No Definido|Bogotá    |V1.80161500                  |701172108     |701820128       |A convenir               |Distrito Capital de Bogotá|EL \nCONTRATISTA se obliga con -RTVC- a prestar sus servicios de apoyo administrativo al área de Gestión administrativa de RTVC; de \nconformidad con el alcance del objeto y las obligaciones en el acápite correspondiente del contrato.                                                       |No definido                |Funcionamiento|0               |52108788           |No             |Carrera 111a No 16 i -11                |180 Dia(s)           |No                              |Centralizada        |No      |No     |No             |No Válido  |En ejecución   |2023-08-30T00:00:00.000  |2023-03-08T00:00:00.000|2023-03-08T00:00:00.000     |NULL                                 |NULL                 |NULL                    |Mujer                     |No                      |CO1.PCCNTR.4738736|52108788                          |Regla aplicable                             |No         |Colombia, Bogotá,  Bogotá     |Contratación régimen especial|451851112       |No definido                          |No definido                            |No definido                   |CO                              |900002583  |AV VILLAS       |RADIO TELEVISION NACIONAL DE COLOMBIA.       |No definido             |No definido                   |JULIA BIBIANA RIVERA AMORTEGUI  |No definido              |EL \nCONTRATISTA se obliga con -RTVC- a prestar sus servicios de apoyo administrativo al área de Gestión administrativa de RTVC; de \nconformidad con el alcance del objeto y las obligaciones en el acápite correspondiente del contrato.                                                       |No                  |No                      |Nacional   |Recursos Propios      |No aplica          |0                                   |CO1.BDOS.4132503 |Julia Bibiana Rivera Amortegui  |No aplica         |Ejecutivo           |0                  |13200000        |0                                                               |783-2023               |No       |13200000 |0             |Tecnologías de la Información y las Comunicaciones|0                                 |0                          |Prestación de servicios|Ahorros       |No definido                        |No definido                          |No definido                 |Cédula de Ciudadanía                      |Cédula de Ciudadanía|NULL                   |{https://community.secop.gov.co/Public/Tendering/OpportunityDetail/Index?noticeUID=CO1.NTC.4133610&isFromPublicArea=True&isModal=true&asPopupView=true}|0               |0                       |13200000          |0              |0           |0                 |13200000                    |13200000               |
# |No D     |No Definido|Bogotá    |V1.80111620                  |700578032     |702626235       |Como acordado previamente|Distrito Capital de Bogotá|PRESTAR SERVICIOS PROFESIONALES ESPECIALIZADOS ORIENTADOS A CONTRIBUIR EN EL PROCESOS DE RELACIONAMIENTO INSTUTICIONAL Y DE GESTIÓN INTERNACIONAL QUE APORTEN AL CUMPLIMIENTO DE LAS METAS DEL PLAN DEPARTAMENTAL DE DESARROLLO ¨GOBERNANDO MAS DE UN PLAN 2024-2028                             |No definido                |Funcionamiento|0               |1082879355         |No             |No Definido                             |300 Dia(s)           |No                              |Centralizada        |No      |No     |No             |No Válido  |En ejecución   |2026-11-18T00:00:00.000  |2026-01-13T00:00:00.000|2026-01-19T00:00:00.000     |NULL                                 |NULL                 |NULL                    |Mujer                     |No                      |CO1.PCCNTR.8846307|Sin Descripcion                   |Servicios profesionales y apoyo a la gestión|No         |Colombia, Bogotá,  Bogotá     |Contratación directa         |No definido     |No definido                          |35.355.189                             |No definido                   |CO                              |899999114  |No definido     |SECRETARIA GENERAL Y DE CERCANIA AL CIUDADANO|No definido             |NATALIA ANDREA FORERO MARiN   |victoria elena noguera avila    |No definido              |PRESTAR SERVICIOS PROFESIONALES ESPECIALIZADOS ORIENTADOS A CONTRIBUIR EN EL PROCESOS DE RELACIONAMIENTO INSTUTICIONAL Y DE GESTIÓN INTERNACIONAL QUE APORTEN AL CUMPLIMIENTO DE LAS METAS DEL PLAN DEPARTAMENTAL DE DESARROLLO ¨GOBERNANDO MAS DE UN PLAN 2024-2028                             |No                  |No                      |Territorial|Distribuido           |No aplica          |0                                   |CO1.BDOS.9463073 |VICTORIA ELENA NOGUERA AVILA    |No aplica         |Ejecutivo           |0                  |0               |67526800                                                        |SGCC-CD-PSP-326-2026   |No       |0        |0             |No aplica/No pertenece                            |0                                 |0                          |Prestación de servicios|No Definido   |No definido                        |Cédula de Ciudadanía                 |No definido                 |Sin Descripcion                           |Cédula de Ciudadanía|NULL                   |{https://community.secop.gov.co/Public/Tendering/OpportunityDetail/Index?noticeUID=CO1.NTC.9475653&isFromPublicArea=True&isModal=true&asPopupView=true}|0               |0                       |67526800          |0              |0           |0                 |67526800                    |67526800               |
# |No D     |No Definido|Valledupar|V1.80111620                  |703639690     |712296920       |No Definido              |Cesar                     |PRESTACIÓN DE SERVICIOS PROFESIONALES DE UN ABOGADO (A) ESPECIALIZADO EN DERECHO AMBIENTAL QUE BRINDE APOYO JURIDICO ESPECIFCO A LA SECRETARIA DE GOBIERNO MUNICIPAL DE VALLEDUPAR.                                                                                                              |No definido                |Funcionamiento|0               |39462274           |No             |calle 16#12-120                         |3 Mes(es)            |No                              |Centralizada        |No      |No     |No             |No Válido  |Modificado     |2021-12-15T00:00:00.000  |2021-09-16T00:00:00.000|2021-09-16T00:00:00.000     |NULL                                 |NULL                 |NULL                    |Mujer                     |No                      |CO1.PCCNTR.2856811|39462274                          |Servicios profesionales y apoyo a la gestión|No         |Colombia,  Cesar ,  Valledupar|Contratación directa         |No definido     |No definido                          |1065578810                             |77186812                      |CO                              |800098911  |BANCO DAVIVIENDA|ALCALDIA MUNICIPAL DE VALLEDUPAR             |No definido             |ANDRES FELIPE MAESTRE LABRADA*|MELISSA JOHANNA GÓMEZ FERNÁNDEZ |LUIS ENRIQUE GALVIS NUÑEZ|PRESTACIÓN DE SERVICIOS PROFESIONALES DE UN ABOGADO (A) ESPECIALIZADO EN DERECHO AMBIENTAL QUE BRINDE APOYO JURIDICO ESPECIFCO A LA SECRETARIA DE GOBIERNO MUNICIPAL DE VALLEDUPAR.                                                                                                              |No                  |No                      |Territorial|Distribuido           |No aplica          |0                                   |CO1.BDOS.2250151 |MELISSA JOHANNA GOMEZ FERNANDEZ |No aplica         |Ejecutivo           |0                  |0               |15000000                                                        |1034-SGR DE 2021       |No       |15000000 |0             |Servicio Público                                  |0                                 |0                          |Prestación de servicios|Ahorros       |No definido                        |Cédula de Ciudadanía                 |Cédula de Ciudadanía        |Cédula de Ciudadanía                      |Cédula de Ciudadanía|2021-10-19T00:00:00.000|{https://community.secop.gov.co/Public/Tendering/OpportunityDetail/Index?noticeUID=CO1.NTC.2252832&isFromPublicArea=True&isModal=true&asPopupView=true}|0               |0                       |15000000          |0              |0           |0                 |15000000                    |15000000               |
# +---------+-----------+----------+-----------------------------+--------------+----------------+-------------------------+--------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------+--------------+----------------+-------------------+---------------+----------------------------------------+---------------------+--------------------------------+--------------------+--------+-------+---------------+-----------+---------------+-------------------------+-----------------------+----------------------------+-------------------------------------+---------------------+------------------------+--------------------------+------------------------+------------------+----------------------------------+--------------------------------------------+-----------+------------------------------+-----------------------------+----------------+-------------------------------------+---------------------------------------+------------------------------+--------------------------------+-----------+----------------+---------------------------------------------+------------------------+------------------------------+--------------------------------+-------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------+------------------------+-----------+----------------------+-------------------+------------------------------------+-----------------+--------------------------------+------------------+--------------------+-------------------+----------------+----------------------------------------------------------------+-----------------------+---------+---------+--------------+--------------------------------------------------+----------------------------------+---------------------------+-----------------------+--------------+-----------------------------------+-------------------------------------+----------------------------+------------------------------------------+--------------------+-----------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+------------------------+------------------+---------------+------------+------------------+----------------------------+-----------------------+
# only showing top 5 rows
#
#
# === COLUMNAS DISPONIBLES ===
# - anno_bpin
# - c_digo_bpin
# - ciudad
# - codigo_de_categoria_principal
# - codigo_entidad
# - codigo_proveedor
# - condiciones_de_entrega
# - departamento
# - descripcion_del_proceso
# - descripcion_documentos_tipo
# - destino_gasto
# - dias_adicionados
# - documento_proveedor
# - documentos_tipo
# - domicilio_representante_legal
# - duraci_n_del_contrato
# - el_contrato_puede_ser_prorrogado
# - entidad_centralizada
# - es_grupo
# - es_pyme
# - espostconflicto
# - estado_bpin
# - estado_contrato
# - fecha_de_fin_del_contrato
# - fecha_de_firma
# - fecha_de_inicio_del_contrato
# - fecha_de_notificaci_n_de_prorrogaci_n
# - fecha_fin_liquidacion
# - fecha_inicio_liquidacion
# - g_nero_representante_legal
# - habilita_pago_adelantado
# - id_contrato
# - identificaci_n_representante_legal
# - justificacion_modalidad_de
# - liquidaci_n
# - localizaci_n
# - modalidad_de_contratacion
# - n_mero_de_cuenta
# - n_mero_de_documento_ordenador_de_pago
# - n_mero_de_documento_ordenador_del_gasto
# - n_mero_de_documento_supervisor
# - nacionalidad_representante_legal
# - nit_entidad
# - nombre_del_banco
# - nombre_entidad
# - nombre_ordenador_de_pago
# - nombre_ordenador_del_gasto
# - nombre_representante_legal
# - nombre_supervisor
# - objeto_del_contrato
# - obligaci_n_ambiental
# - obligaciones_postconsumo
# - orden
# - origen_de_los_recursos
# - pilares_del_acuerdo
# - presupuesto_general_de_la_nacion_pgn
# - proceso_de_compra
# - proveedor_adjudicado
# - puntos_del_acuerdo
# - rama
# - recursos_de_credito
# - recursos_propios
# - recursos_propios_alcald_as_gobernaciones_y_resguardos_ind_genas_
# - referencia_del_contrato
# - reversion
# - saldo_cdp
# - saldo_vigencia
# - sector
# - sistema_general_de_participaciones
# - sistema_general_de_regal_as
# - tipo_de_contrato
# - tipo_de_cuenta
# - tipo_de_documento_ordenador_de_pago
# - tipo_de_documento_ordenador_del_gasto
# - tipo_de_documento_supervisor
# - tipo_de_identificaci_n_representante_legal
# - tipodocproveedor
# - ultima_actualizacion
# - urlproceso
# - valor_amortizado
# - valor_de_pago_adelantado
# - valor_del_contrato
# - valor_facturado
# - valor_pagado
# - valor_pendiente_de
# - valor_pendiente_de_ejecucion
# - valor_pendiente_de_pago
#
# === INFORMACIÓN DEL DATASET ===
# Registros totales: 1,000
# Columnas totales: 87
#
# === COLUMNAS SELECCIONADAS (9) ===
# - referencia_del_contrato
# - nit_entidad
# - nombre_entidad
# - departamento
# - ciudad
# - tipo_de_contrato
# - valor_del_contrato
# - fecha_de_firma
# - estado_contrato
#
# === GUARDANDO EN FORMATO PARQUET ===
# Ruta: /opt/spark-data/raw/secop_contratos.parquet
# Datos guardados exitosamente en formato Parquet
#
# === VERIFICACIÓN ===
# Registros en Parquet: 1,000
# Columnas en Parquet: 9
#
# ============================================================
# RESUMEN DE INGESTA
# ============================================================
# ✓ Datos descargados desde API Socrata
# ✓ Registros procesados: 1,000
# ✓ Formato de salida: Parquet
# ✓ Ubicación: /opt/spark-data/raw/secop_contratos.parquet
# ============================================================
# SparkSession finalizada
