# %%
from pyspark.sql import SparkSession
from pyspark.ml.regression import LinearRegression
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.sql.functions import col

# %%
spark = SparkSession.builder \
    .appName("SECOP_RegresionLineal") \
    .master("local[*]") \
    .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/14 15:49:45 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/02/14 15:49:46 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
# Cargar datos
df = spark.read.parquet("/opt/spark-data/processed/secop_ml_ready.parquet")

# Renombrar columnas para consistencia
df = df.withColumnRenamed("valor_del_contrato_num", "label") \
       .withColumnRenamed("features_pca", "features")

# Filtrar valores nulos
df = df.filter(col("label").isNotNull())
print(f"Registros: {df.count():,}")
print(f"Columnas: {len(df.columns)}")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Cargar datos
# ----> 2 df = spark.read.parquet("/opt/spark-data/processed/secop_ml_ready.parquet")
#       4 # Renombrar columnas para consistencia
#       5 df = df.withColumnRenamed("valor_del_contrato_num", "label") \
#       6        .withColumnRenamed("features_pca", "features")
#
# File /opt/spark/python/pyspark/sql/readwriter.py:544, in DataFrameReader.parquet(self, *paths, **options)
#     533 int96RebaseMode = options.get("int96RebaseMode", None)
#     534 self._set_opts(
#     535     mergeSchema=mergeSchema,
#     536     pathGlobFilter=pathGlobFilter,
#    (...)    541     int96RebaseMode=int96RebaseMode,
#     542 )
# --> 544 return self._df(self._jreader.parquet(_to_seq(self._spark._sc, paths)))
#
# File /opt/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /opt/spark/python/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [PATH_NOT_FOUND] Path does not exist: file:/opt/spark-data/processed/secop_ml_ready.parquet.
# 26/02/14 15:49:56 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
train, test = df.randomSplit([0.7,0.3], seed = 45)

print(train.count())
print(test.count())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 train, test = df.randomSplit([0.7,0.3], seed = 45)
#       3 print(train.count())
#       4 print(test.count())
#
# NameError: name 'df' is not defined

# %%
lr = LinearRegression(features_scaled="features",
                     valor_del_contrato="label",
                     maxIter=100,
                     regParam=0.0,
                     elasticNetParam=0.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 lr = LinearRegression(features_scaled="features",
#       2                      valor_del_contrato="label",
#       3                      maxIter=100,
#       4                      regParam=0.0,
#       5                      elasticNetParam=0.0)
#
# File /opt/spark/python/pyspark/__init__.py:139, in keyword_only.<locals>.wrapper(self, *args, **kwargs)
#     137     raise TypeError("Method %s forces keyword arguments." % func.__name__)
#     138 self._input_kwargs = kwargs
# --> 139 return func(self, **kwargs)
#
# TypeError: LinearRegression.__init__() got an unexpected keyword argument 'features_scaled'

# %%
lr_model=lr.fit(train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 lr_model=lr.fit(train)
#
# NameError: name 'lr' is not defined

# %%
lr_model.getSolver()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 lr_model.getSolver()
#
# NameError: name 'lr_model' is not defined

# %%
lr_model.summary.rootMeanSquaredError
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 lr_model.summary.rootMeanSquaredError
#
# NameError: name 'lr_model' is not defined

# %%
lr_model.summary.r2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 lr_model.summary.r2
#
# NameError: name 'lr_model' is not defined

# %%
predictions= lr_model.transform(test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 predictions= lr_model.transform(test)
#
# NameError: name 'lr_model' is not defined

# %%
evaluator_rmse = RegressionEvaluator(labelCol="label",
                                    predictionCol="prediction",
                                    metricName="rmse")
evaluator_mae = RegressionEvaluator(labelCol="label",
                                    predictionCol="prediction",
                                    metricName="mae")

evaluator_r2 = RegressionEvaluator(labelCol="label",
                                    predictionCol="prediction",
                                    metricName="r2")

rmse = evaluator_rmse.evaluate(predictions)
mae = evaluator_mae.evaluate(predictions)
r2 = evaluator_r2.evaluate(predictions)

print("="*60)
print("rmse:", rmse)
print("mae:",mae)
print("r2:",r2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 12
#       4 evaluator_mae = RegressionEvaluator(labelCol="label",
#       5                                     predictionCol="prediction",
#       6                                     metricName="mae")
#       8 evaluator_r2 = RegressionEvaluator(labelCol="label",
#       9                                     predictionCol="prediction",
#      10                                     metricName="r2")
# ---> 12 rmse = evaluator_rmse.evaluate(predictions)
#      13 mae = evaluator_mae.evaluate(predictions)
#      14 r2 = evaluator_r2.evaluate(predictions)
#
# NameError: name 'predictions' is not defined

# %%
# Guardar modelo
model_path = "/opt/spark-data/processed/linear_regression_model"
lr_model.save(model_path)
print(f"\nModelo guardado en: {model_path}")

# %%
# Guardar predicciones
predictions_path = "/opt/spark-data/processed/predictions_lr.parquet"
predictions.write.mode("overwrite").parquet(predictions_path)
print(f"Predicciones guardadas en: {predictions_path}")

# %%
spark.stop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 # Guardar modelo
#       2 model_path = "/opt/spark-data/processed/linear_regression_model"
# ----> 3 lr_model.save(model_path)
#       4 print(f"\nModelo guardado en: {model_path}")
#       6 # %%
#       7 # Guardar predicciones
#
# NameError: name 'lr_model' is not defined
